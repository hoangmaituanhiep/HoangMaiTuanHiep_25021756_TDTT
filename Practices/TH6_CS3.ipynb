# %%
#W6A1
x = list(map(int, input().split()))

tempt = []

for i in range(len(x)):
    if x[i] not in tempt:
        tempt.append(x[i])

print(tempt)
# Out:
#  1 2 4 5 1 2 3 4
# [1, 2, 4, 5, 3]

# %%
#W6A2
sum = 0

x = list(map(int, input().split()))

for i in x:
    sum+=i

print(sum)
# Out:
#  1 2 3 4 5
# 15

# %%
#W6A3
tup = tuple(map(int, input().split()))
k = int(input())
